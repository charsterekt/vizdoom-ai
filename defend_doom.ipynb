# %% [markdown]
# This file is for all intents and purposes a copy of the `basic_doom` scenario file, but with minor modifications to account for loading a different scenario config and different parameters such as availability of different and more game variables. We will also need to tune parameters, the `env` class, and a different reward structure. <br>
#
# We will be tackling the Defend Center scenario in this file. Note: Doomguy will eventually die due to running out of ammo. Tragic.

# %%
# Imports 
from vizdoom import *  # Game env
import random  # Random action sampling
import time  # For sleeping+
import numpy as np  # Identity matrix and more

# We're going to need to define some shapes to get our frame data working with gym
# The way we do this is through Spaces
# The types we're going to use are Box and Discrete
# Box is an array of any shape
# Discrete is a set of discrete binary actions
from gym import Env  # OpenAI gym base class
from gym.spaces import Box, Discrete  # Spaces for gym
import cv2  # OpenCV for image processing
import matplotlib.pyplot as plt

# %matplotlib inline

# Importing dependencies for training
import os  # For file nav
# Callback class for RL
from stable_baselines3.common.callbacks import BaseCallback
# We can use this to check our environment's format
from stable_baselines3.common import env_checker
# PPO for training
from stable_baselines3 import PPO
# Eval policy for testing models
from stable_baselines3.common.evaluation import evaluate_policy
# Monitor wrapper
from stable_baselines3.common.monitor import Monitor

# %%
# Create random actions
actions = np.identity(3, dtype=np.uint8)
actions

# Index 0 represents move left
# Index 1 represents move right
# Index 2 represents shoot
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]], dtype=uint8)

# %%
# Example of a Discrete space
Discrete(3).sample()  # Returns 0, 1 or 2
# We can use these for our action indices
# Out:
# 1

# %%
# For example:
actions[Discrete(3).sample()]
# Out:
# array([0, 1, 0], dtype=uint8)

# %%
# Example of a Box space
Box(low=0, high=10, shape=(10, 10), dtype=np.uint8).sample()  # Returns a random array
# We will use this for our frame data
# In this case the shape would be passed as (640, 480) to fit the screen
# Out:
# array([[ 7,  9,  9,  1,  8,  4,  7,  3,  8,  1],
#        [ 9, 10,  3,  1, 10,  1,  7,  8,  2,  2],
#        [ 7,  9,  3,  9,  2,  2,  9,  3,  8,  1],
#        [ 4,  7,  6,  9,  2,  4,  5,  9,  1,  9],
#        [ 3,  9,  9,  0,  4,  4,  4,  1, 10,  5],
#        [ 6, 10,  8, 10,  5,  6,  4,  7,  9,  0],
#        [ 4,  0,  4, 10,  5,  7,  9, 10,  1,  0],
#        [ 6, 10,  0,  2,  1,  6,  2,  4,  0,  6],
#        [ 1,  0,  0,  0,  2,  7,  4,  3, 10,  2],
#        [ 2,  5,  9,  8,  8,  6,  5,  1,  8, 10]], dtype=uint8)

# %%
# Create ViZDoom OpenAI Gym Environment
class VizDoomGym(Env):  # inherit from the Env base class
    # Initialization method
    def __init__(self, render=False):  # Render false lets us train faster
        # Inherit from env
        super().__init__()
        # Game setup
        self.game = DoomGame()
        # Different config loaded. Optionally you can turn it into a param for the class
        self.game.load_config("git_doom/ViZDoom/scenarios/defend_the_center.cfg")
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        self.game.init()  # Start the game after setting the params

        # Define the action and observation space
        self.observation_space = Box(low=0, high=255, 
            shape=(100, 160, 1), dtype=np.uint8)  # Resized shapes
        self.action_space = Discrete(3)  # Straightforward 

    # Perform an action/take a step in the environment
    def step(self, action):
        # Specify action and take step
        actions = np.identity(3, dtype=np.uint8)
        reward = self.game.make_action(actions[action], 4)  # 4 frames skipped

        # Get the other stuff we need to return, with error safety
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            # Currently the only game variable in use in the basic scenario
            info = ammo
        else:
            state = np.zeros(self.observation_space.shape)
            info = 0  # Dummy descriptor
        
        info = {"info": info}
        done = self.game.is_episode_finished()

        return state, reward, done, info
    
    # Gray Scale and resize the game frame with cv2
    def grayscale(self, observation):  # Effectively passing our game frame
        # The image is the same we're just moving the colour channels to the last index
        # That's the format np expects
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160, 100), interpolation=cv2.INTER_CUBIC)  # Make smaller
        state = np.reshape(resize, (100, 160, 1))  # Reshape to fit our space
        return state

    # Start a new game
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state) 

    # Close the environment/game
    def close(self):
        self.game.close()

    # Pre-Defined in VizDoom, staying pass for now
    # Usually where we define how to render the game or environment
    def render(self):
        pass

# %%
# Create environment
env = VizDoomGym(render=True)

# Testing
state = env.reset()
print(state.shape)

print(f'Observation space shape: {env.observation_space.sample().shape}')
print(f'Action space: {env.action_space.sample()}')

print(env.step(2))

plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# Check if the environment is set up correctly with SB3's checker
env_checker.check_env(env)  # Will throw error if not
print("Environment is in correct format")

env.close()
# Out:
# (100, 160, 1)
# Observation space shape: (100, 160, 1)
# Action space: 1
# (array([[[10],
#         [11],
#         [ 6],
#         ...,
#         [10],
#         [10],
#         [ 6]],
#
#        [[ 7],
#         [10],
#         [ 9],
#         ...,
#         [ 9],
#         [11],
#         [ 7]],
#
#        [[ 5],
#         [ 5],
#         [ 7],
#         ...,
#         [ 3],
#         [ 6],
#         [ 7]],
#
#        ...,
#
#        [[50],
#         [63],
#         [56],
#         ...,
#         [47],
#         [67],
#         [52]],
#
#        [[16],
#         [36],
#         [47],
#         ...,
#         [62],
#         [61],
#         [48]],
#
#        [[22],
#         [15],
#         [31],
#         ...,
#         [64],
#         [42],
#         [45]]], dtype=uint8), 0.0, False, {'info': 26.0})
# Environment is in correct format

# %%
# Standard Training and Logging Callback, refer to SB3 docs
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
    
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, "best_model_{}".format(self.n_calls))
            self.model.save(model_path)

# %%
# Directory paths
CHECKPOINT_DIR_BASIC = './train/train_defend'
LOG_DIR_BASIC = './logs/log_defend'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, 
    save_path=CHECKPOINT_DIR_BASIC)
# This saves the pytorch model's weights every 10000 steps

# %%
# The algorithm we're going to use to train our model is PPO
# The PPO implementation can be found in Stable Baselines 3
# Create a non rendered environment for training
train_env = VizDoomGym()
print("Creating training environment...")

# Create an instance of PPO
model = PPO(
    'CnnPolicy',  # Since we're using images
    train_env,  # Our environment for training
    tensorboard_log=LOG_DIR_BASIC,  # Where to save our logs
    verbose=1,  # Verbosity level
    learning_rate=0.0001,  # Learning rate
    n_steps=4096,  # Number of steps to train
)
# Out:
# Creating training environment...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# Training loop
model.learn(
    total_timesteps=100000,  # Number of steps to train
    callback=callback,  # Callback to save the model
)
# Out:
# Logging to ./logs/log_defend\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.7     |
# |    ep_rew_mean     | 0.226    |
# | time/              |          |
# |    fps             | 77       |
# |    iterations      | 1        |
# |    time_elapsed    | 52       |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.3        |
# |    ep_rew_mean          | 0.24        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 2           |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003533938 |
# |    clip_fraction        | 0.00303     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0505      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0397      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.2        |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 3           |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010585681 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00746     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | 1.88        |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 4           |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012270741 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.026      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 2.8         |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 5           |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013137367 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0436      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 0.139       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | 3.36        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017793417 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0258     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0311     |
# |    value_loss           | 0.157       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 120        |
# |    ep_rew_mean          | 3.98       |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 7          |
# |    time_elapsed         | 392        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01921383 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.891     |
# |    explained_variance   | 0.678      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0125     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0345    |
# |    value_loss           | 0.163      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 123      |
# |    ep_rew_mean          | 4.48     |
# | time/                   |          |
# |    fps                  | 72       |
# |    iterations           | 8        |
# |    time_elapsed         | 451      |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 0.02139  |
# |    clip_fraction        | 0.211    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.883   |
# |    explained_variance   | 0.732    |
# |    learning_rate        | 0.0001   |
# |    loss                 | -0.0044  |
# |    n_updates            | 70       |
# |    policy_gradient_loss | -0.0372  |
# |    value_loss           | 0.165    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 126      |
# |    ep_rew_mean          | 5.07     |
# | time/                   |          |
# |    fps                  | 72       |
# |    iterations           | 9        |
# |    time_elapsed         | 509      |
# |    total_timesteps      | 36864    |
# | train/                  |          |
# |    approx_kl            | 0.019706 |
# |    clip_fraction        | 0.216    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.862   |
# |    explained_variance   | 0.736    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 0.0193   |
# |    n_updates            | 80       |
# |    policy_gradient_loss | -0.0406  |
# |    value_loss           | 0.166    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 129        |
# |    ep_rew_mean          | 5.5        |
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 10         |
# |    time_elapsed         | 568        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02193581 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.814     |
# |    explained_variance   | 0.789      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0083    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0377    |
# |    value_loss           | 0.167      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | 5.84        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 11          |
# |    time_elapsed         | 626         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.023386735 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00456    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 0.16        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 138        |
# |    ep_rew_mean          | 6.29       |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 12         |
# |    time_elapsed         | 683        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02344567 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.765     |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.00766    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0399    |
# |    value_loss           | 0.166      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 6.77        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 13          |
# |    time_elapsed         | 742         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.024753202 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0456     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 7.15        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 14          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.026577279 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.715      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0396     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 0.152       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 157        |
# |    ep_rew_mean          | 7.7        |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 15         |
# |    time_elapsed         | 859        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02842116 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.706     |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0292    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0445    |
# |    value_loss           | 0.166      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | 8.05        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 16          |
# |    time_elapsed         | 918         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.028529357 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0165     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 0.129       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | 8.3         |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 17          |
# |    time_elapsed         | 974         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.027364299 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0338      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 8.74        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 18          |
# |    time_elapsed         | 1033        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.027407851 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0319     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | 8.89        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 19          |
# |    time_elapsed         | 1092        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.028927574 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.015       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0413     |
# |    value_loss           | 0.134       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 176        |
# |    ep_rew_mean          | 9.24       |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 20         |
# |    time_elapsed         | 1150       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.03227908 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.633     |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.029     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0435    |
# |    value_loss           | 0.139      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 9.34        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 21          |
# |    time_elapsed         | 1206        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.029219612 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.644      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.051      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 177        |
# |    ep_rew_mean          | 9.43       |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 22         |
# |    time_elapsed         | 1262       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03215473 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.651     |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0437    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0434    |
# |    value_loss           | 0.115      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 9.77        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 23          |
# |    time_elapsed         | 1318        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.031229597 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00997    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0423     |
# |    value_loss           | 0.135       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 181        |
# |    ep_rew_mean          | 9.94       |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 24         |
# |    time_elapsed         | 1377       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.03425394 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.639     |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00925   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0466    |
# |    value_loss           | 0.129      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 25          |
# |    time_elapsed         | 1439        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.038487297 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0311     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0411     |
# |    value_loss           | 0.126       |
# -----------------------------------------

# %%
train_env.close()  # Cleanup

# %%
# Now we test the model, fully trained

# Load the model's most recent and best version
model = PPO.load("./train/train_defend/best_model_100000")  # Can also use model.load

# Test and evaluate model stats

# Creat a test environment
test_env = VizDoomGym(render=True)
# Wrap with SB3 Monitor class for error safety
test_env = Monitor(test_env, allow_early_resets=False)  # I don't want logs for this, you may set it to a log dir
# Evaluate mean reward for 100 games
print("Ripping and Tearing...")
mean_reward, _ = evaluate_policy(model, test_env, n_eval_episodes=10)
print("It is done")
print(f"Mean reward: {mean_reward}")
test_env.close()
# Out:
# Ripping and Tearing...
# It is done
# Mean reward: 12.2

# %%
# Use a loop to slow things down for visual clarity without evaluate_policy
test_env = VizDoomGym(render=True)
test_env = Monitor(test_env, allow_early_resets=False)

for episode in range(5):  # Play 5 games
    obs = test_env.reset()  # Store the current frame in observation
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)  # Get the action based on the observation
        obs, reward, done, info = test_env.step(action)  # Get info from step
        time.sleep(0.06)  # Have a small pause
        total_reward += reward  # Update the reward
    print(f"Episode {episode+1} reward: {total_reward}")
    time.sleep(2)  # Between each episode

test_env.close()
# Out:
# Episode 1 reward: 11.0
# Episode 2 reward: 7.0
# Episode 3 reward: 9.0
# Episode 4 reward: 12.0
# Episode 5 reward: 13.0
